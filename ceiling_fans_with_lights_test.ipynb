# %%
url = 'https://apionline.homedepot.com/federation-gateway/graphql?opname=s'

# %%
import json

# %%
with open('payload.json', 'w') as f:
    json.dump(payload, f, indent=4)

# %%
headers ={
    "accept": "*/*",
    "accept-encoding": "gzip, deflate, br, zstd",
    "accept-language": "en-US,en;q=0.9",
    "content-type": "application/json",
    "cookie": "QuantumMetricUserID=a2899551da75d63cbb97689ca698cdc7; HD_DC=origin; at_check=true; AMCVS_F6421253512D2C100A490D45%40AdobeOrg=1; THD_PERSIST=; THD_CACHE_NAV_PERSIST=; DELIVERY_ZIP_TYPE=DEFAULT; thda.s=7fe92dab-a91d-ce53-fa91-8a2c1a312ad2; thda.u=663cb1bf-11fb-6c11-8ac5-2e9366add3ad; _px_f394gi7Fvmc43dfg_user_id=YWQyYzZhZDEtMzNmOC0xMWVmLTliMzEtM2IyY2ZiYWFiMGY0; ajs_anonymous_id=d7861241-60b9-44eb-9d5a-fbbddaa73695; thda.m=76721570817405704221197643616351372219; aam_uuid=76470141564458929311223218151539404238; trx=6582811316921143341; _gcl_au=1.1.17785004.1719432867; _ga_M8YZQYQTBJ=GS1.2.1719934627.1.1.1719934657.0.0.0; THD_MCC_ID=1fabb362-71e8-41d0-a55f-f5e4d436415f; _gac_UA-32593878-1=1.1722967269.CjwKCAjwk8e1BhALEiwAc8MHiOM4vYyAYWP7sZDUfls5QtoSnk7uhKcYKqe8AAqUFbM6KUELwbuS4RoCItkQAvD_BwE; _gcl_aw=GCL.1722967269.CjwKCAjwk8e1BhALEiwAc8MHiOM4vYyAYWP7sZDUfls5QtoSnk7uhKcYKqe8AAqUFbM6KUELwbuS4RoCItkQAvD_BwE; _gcl_dc=GCL.1722967269.CjwKCAjwk8e1BhALEiwAc8MHiOM4vYyAYWP7sZDUfls5QtoSnk7uhKcYKqe8AAqUFbM6KUELwbuS4RoCItkQAvD_BwE; _gcl_gs=2.1.k1$i1722967264; kndctr_F6421253512D2C100A490D45_AdobeOrg_identity=CiY3NjcyMTU3MDgxNzQwNTcwNDIyMTE5NzY0MzYxNjM1MTM3MjIxOVIQCNDw2%2DWdMhgBKgNPUjIwA%5FABvvPb5Z0y; DELIVERY_ZIP=91786; _ga=GA1.1.184946466.1719432866; _ga_9H2R4ZXG4J=GS1.1.1725992759.10.0.1725992759.60.0.0; THDSSO=...; PF=ouFvVLf7PYWbkJjmImpbnLOGCJXYnMUivKzYNJ90Wmwf; SMSESSION=...; PF.PERSISTENT=eyJhbGciOiJkaXIiLCJlbmMiOiJBMTI4Q0JDLUhTMjU2In0..qb5YU2E_KtrUsssCprzGDA.um6Zv8s2iY7Eo7MBqIDeI4gdS_GNc6KuXdyE3R2mFqbFoZDW-xJ1beaOpNiz3YIsh3EzykTAQbnmlm0M0Zn5rkM5zH7cR-TlR9M5OQAMeO4.t3gHfhocqiAhKb0Vv0vtEg; THD_NR=1; THD_SESSION=; THD_CACHE_NAV_SESSION=; ads=d4583d50af052f3ac724e7d6c047b45e; bm_ss=ab8e18ef4e; bm_sz=2266494ABCF5AF960D93B00012AF4D33~...~3486001~3551814; AKA_A2=A; THD_LOCALIZER=%7B%22WORKFLOW%22%3A%22LOCALIZED_BY_GPS_MEDIUM%22%2C%22THD_FORCE_LOC%22%3A%221%22%2C%22THD_INTERNAL%22%3A%220%22%2C%22THD_LOCSTORE%22%3A%22687%2BUpland%20-%20Upland%2C%20CA%2B%22%2C%22THD_STRFINDERZIP%22%3A%2291786%22%2C%22THD_STORE_HOURS%22%3A%221%3B7%3A00-20%3A00%3B2%3B6%3A00-22%3A00%3B3%3B6%3A00-22%3A00%3B4%3B6%3A00-22%3A00%3B5%3B6%3A00-22%3A00%3B6%3B6%3A00-22%3A00%3B7%3B6%3A00-22%3A00%22%2C%22THD_STORE_HOURS_EXPIRY%22%3A1726616725%7D; bm_sv=28C472E8FC14BB009E242313E6B914B1~~1; bm_mi=138FA0A117F80B4D62E970610DA0FFA4~~1; ak_bmsc=04B402A42282FDEBBBF7F3BB1EA2B465~000000000000000000000000000000~...; bm_lso=C49B3B6E9D2B9056A4730E03F692F10C09AAB849FDA8D39DAE41EB10590E4F6C~...^1726613195589; s_sq=%5B%5BB%5D%5D; s_sess=%20fabrickIdfromInDb%3D%2522E1%253AXbQXXulLu04o_qtIPPxOEj0A6448gmJUZI3OfW9dlhxbKhzcOh5SbbO4w4v_Slr1KVzpxu7g6Eiw2oHVUWG9bUw6QPhO63_fx9CX4gp4JzI%2522%3B%20s_pv_pName%3Dlighting%253Eceiling%2520fans%253Eceiling%2520fans%2520with%2520lights%3B%20s_pv_pType%3Dcat%2520plp%3B%20s_pv_cmpgn%3D%3B%20s_pv_pVer%3Dhd%2520home%2520v1%3B%20stsh%3D%3B%20s_cc%3Dtrue%3B; forterToken=629e72db133c4fdca594832c79f2e0f9_1726613209659_361_dUAL43-mnts-ants_13ck; _abck=40320029DE6C666FA8FAA0AF7F138B10~0~...~-1~-1~-1; bm_s=; bm_so=7A015FF48974F07B4BE39353AC87659D65E048A5CB6E2EA39038D19AFABC1D1A~...; s_pers=%20s_nr365%3D1726613648447-Repeat%7C1758149648447%3B%20s_dslv%3D1726613648448%7C1821221648448%3B; mbox=session#45a3d32433d14d01a8aacbe01e448ae1#1726615509; AMCV_F6421253512D2C100A490D45%40AdobeOrg=1585540135%7CMCMID%7C76721570817405704221197643616351372219%7CMCAAMLH-1721833895%7C9%7CMCAAMB-1721833895%7CRKhpRz8krg2tLO6pguXWp5olkAcUniQYPHaMWWgdJ3xzPWQmdj0y%7CMCOPTOUT-1726620848s%7CNONE%7CMCCIDH%7C-1985754735%7CvVersion%7C4.4.0",
    "Origin": "https://www.homedepot.com",
    "Priority": "u=1, i",
    "Referer": "https://www.homedepot.com/",
    "Sec-CH-UA": "\"Chromium\";v=\"128\", \"Not;A=Brand\";v=\"24\", \"Google Chrome\";v=\"128\"",
    "Sec-CH-UA-Mobile": "?0",
    "Sec-CH-UA-Platform": "\"Windows\"",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-site",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36",
    "X-Api-Cookies": "{\"x-user-id\":\"663cb1bf-11fb-6c11-8ac5-2e9366add3ad\"}",
    "X-Cloud-Trace-Context": "30fc70f0fd794101b2267b9ab3dba720/1;o=1",
    "X-Current-Url": "/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/N-5yc1vZcjnu",
    "X-Debug": "false",
    "X-Experience-Name": "hd-home",
    "X-Hd-Dc": "origin",
    "X-Parent-Trace-Id": "4c4fb9b96ebaf4bdc3d48775a1cdf0c1/12620270206831539013"
}

# %%
payload = {"operationName":"searchModel","variables":{"storefilter":"ALL","channel":"DESKTOP","skipInstallServices":"false","skipSpecificationGroup":"false","skipFavoriteCount":"false","skipKPF":"false","skipDiscoveryZones":"false","skipBuyitagain":"true","additionalSearchParams":{"sponsored":"true","mcvisId":"76721570817405704221197643616351372219","deliveryZip":"91786","multiStoreIds":[]},"filter":{},"navParam":"5yc1vZcjnu","orderBy":{"field":"TOP_SELLERS","order":"ASC"},"pageSize":48,"startIndex":96,"storeId":"687"},"query":"query searchModel($keyword: String, $navParam: String, $storefilter: StoreFilter = ALL, $storeId: String, $itemIds: [String], $channel: Channel = DESKTOP, $additionalSearchParams: AdditionalParams, $loyaltyMembershipInput: LoyaltyMembershipInput, $startIndex: Int, $pageSize: Int, $orderBy: ProductSort, $filter: ProductFilter, $zipCode: String, $skipInstallServices: Boolean = true, $skipSpecificationGroup: Boolean = false, $skipFavoriteCount: Boolean = false, $skipKPF: Boolean = false, $dataSource: String, $skipDiscoveryZones: Boolean = true, $skipBuyitagain: Boolean = true) {\n  searchModel(\n    keyword: $keyword\n    navParam: $navParam\n    storefilter: $storefilter\n    storeId: $storeId\n    itemIds: $itemIds\n    channel: $channel\n    additionalSearchParams: $additionalSearchParams\n    loyaltyMembershipInput: $loyaltyMembershipInput\n  ) {\n    metadata {\n      hasPLPBanner\n      categoryID\n      analytics {\n        semanticTokens\n        dynamicLCA\n        __typename\n      }\n      canonicalUrl\n      searchRedirect\n      clearAllRefinementsURL\n      contentType\n      h1Tag\n      isStoreDisplay\n      productCount {\n        inStore\n        __typename\n      }\n      stores {\n        storeId\n        storeName\n        address {\n          postalCode\n          __typename\n        }\n        nearByStores {\n          storeId\n          storeName\n          distance\n          address {\n            postalCode\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    id\n    searchReport {\n      totalProducts\n      didYouMean\n      correctedKeyword\n      keyword\n      pageSize\n      searchUrl\n      sortBy\n      sortOrder\n      startIndex\n      __typename\n    }\n    relatedResults {\n      universalSearch {\n        title\n        __typename\n      }\n      relatedServices {\n        label\n        __typename\n      }\n      visualNavs {\n        label\n        imageId\n        webUrl\n        categoryId\n        imageURL\n        __typename\n      }\n      visualNavContainsEvents\n      relatedKeywords {\n        keyword\n        __typename\n      }\n      __typename\n    }\n    products(\n      startIndex: $startIndex\n      pageSize: $pageSize\n      orderBy: $orderBy\n      filter: $filter\n    ) {\n      itemId\n      dataSources\n      identifiers {\n        canonicalUrl\n        brandName\n        itemId\n        productLabel\n        productType\n        specialOrderSku\n        storeSkuNumber\n        isSuperSku\n        parentId\n        sampleId\n        modelNumber\n        __typename\n      }\n      media {\n        images {\n          url\n          type\n          subType\n          sizes\n          __typename\n        }\n        __typename\n      }\n      pricing(storeId: $storeId) {\n        value\n        alternatePriceDisplay\n        alternate {\n          bulk {\n            pricePerUnit\n            thresholdQuantity\n            value\n            __typename\n          }\n          unit {\n            caseUnitOfMeasure\n            unitsOriginalPrice\n            unitsPerCase\n            value\n            __typename\n          }\n          __typename\n        }\n        original\n        mapAboveOriginalPrice\n        message\n        preferredPriceFlag\n        promotion {\n          type\n          description {\n            shortDesc\n            longDesc\n            __typename\n          }\n          dollarOff\n          percentageOff\n          promotionTag\n          savingsCenter\n          savingsCenterPromos\n          specialBuySavings\n          specialBuyDollarOff\n          specialBuyPercentageOff\n          dates {\n            start\n            end\n            __typename\n          }\n          __typename\n        }\n        specialBuy\n        unitOfMeasure\n        clearance {\n          value\n          dollarOff\n          percentageOff\n          unitsClearancePrice\n          __typename\n        }\n        __typename\n      }\n      reviews {\n        ratingsReviews {\n          averageRating\n          totalReviews\n          __typename\n        }\n        __typename\n      }\n      info {\n        swatches {\n          isSelected\n          itemId\n          label\n          swatchImgUrl\n          url\n          value\n          __typename\n        }\n        hidePrice\n        ecoRebate\n        quantityLimit\n        categoryHierarchy\n        sskMin\n        sskMax\n        unitOfMeasureCoverage\n        wasMaxPriceRange\n        wasMinPriceRange\n        productSubType {\n          name\n          link\n          __typename\n        }\n        customerSignal {\n          previouslyPurchased\n          __typename\n        }\n        isBuryProduct\n        isGenericProduct\n        returnable\n        isLiveGoodsProduct\n        isSponsored\n        sponsoredMetadata {\n          campaignId\n          placementId\n          slotId\n          sponsoredId\n          trackSource\n          __typename\n        }\n        globalCustomConfigurator {\n          customExperience\n          __typename\n        }\n        augmentedReality\n        sponsoredBeacon {\n          onClickBeacon\n          onViewBeacon\n          onClickBeacons\n          onViewBeacons\n          __typename\n        }\n        productDepartmentId\n        paintBrand\n        dotComColorEligible\n        totalNumberOfOptions\n        samplesAvailable\n        classNumber\n        hasSubscription\n        productDepartment\n        __typename\n      }\n      taxonomy {\n        breadCrumbs {\n          label\n          __typename\n        }\n        __typename\n      }\n      details {\n        installation {\n          serviceType\n          __typename\n        }\n        collection {\n          name\n          url\n          collectionId\n          __typename\n        }\n        highlights\n        __typename\n      }\n      fulfillment(storeId: $storeId, zipCode: $zipCode) {\n        anchorStoreStatus\n        anchorStoreStatusType\n        backordered\n        backorderedShipDate\n        bossExcludedShipStates\n        excludedShipStates\n        seasonStatusEligible\n        fulfillmentOptions {\n          type\n          fulfillable\n          services {\n            deliveryTimeline\n            deliveryDates {\n              startDate\n              endDate\n              __typename\n            }\n            deliveryCharge\n            dynamicEta {\n              hours\n              minutes\n              __typename\n            }\n            hasFreeShipping\n            freeDeliveryThreshold\n            locations {\n              curbsidePickupFlag\n              isBuyInStoreCheckNearBy\n              distance\n              inventory {\n                isOutOfStock\n                isInStock\n                isLimitedQuantity\n                isUnavailable\n                quantity\n                maxAllowedBopisQty\n                minAllowedBopisQty\n                __typename\n              }\n              isAnchor\n              locationId\n              state\n              storeName\n              storePhone\n              type\n              __typename\n            }\n            type\n            totalCharge\n            deliveryMessage\n            __typename\n          }\n          __typename\n        }\n        onlineStoreStatus\n        onlineStoreStatusType\n        fulfillmentBundleMessage\n        __typename\n      }\n      installServices(storeId: $storeId, zipCode: $zipCode) @skip(if: $skipInstallServices) {\n        scheduleAMeasure\n        gccCarpetDesignAndOrderEligible\n        __typename\n      }\n      availabilityType {\n        type\n        buyable\n        discontinued\n        status\n        __typename\n      }\n      badges(storeId: $storeId) {\n        name\n        label\n        __typename\n      }\n      dataSource\n      specificationGroup @skip(if: $skipSpecificationGroup) {\n        specifications {\n          specName\n          specValue\n          __typename\n        }\n        specTitle\n        __typename\n      }\n      favoriteDetail @skip(if: $skipFavoriteCount) {\n        count\n        __typename\n      }\n      bundleFlag\n      keyProductFeatures @skip(if: $skipKPF) {\n        keyProductFeaturesItems {\n          features {\n            name\n            refinementId\n            refinementUrl\n            value\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      bundleItems {\n        id\n        quantity\n        __typename\n      }\n      __typename\n    }\n    taxonomy {\n      brandLinkUrl\n      breadCrumbs {\n        browseUrl\n        creativeIconUrl\n        deselectUrl\n        dimensionId\n        dimensionName\n        label\n        refinementKey\n        url\n        __typename\n      }\n      __typename\n    }\n    templates\n    discoveryZones @skip(if: $skipDiscoveryZones) {\n      products(dataSource: $dataSource) {\n        itemId\n        dataSources\n        badges(storeId: $storeId) {\n          name\n          __typename\n        }\n        info {\n          isSponsored\n          sponsoredMetadata {\n            campaignId\n            placementId\n            slotId\n            sponsoredId\n            trackSource\n            __typename\n          }\n          sponsoredBeacon {\n            onClickBeacon\n            onViewBeacon\n            onClickBeacons\n            onViewBeacons\n            __typename\n          }\n          productSubType {\n            name\n            __typename\n          }\n          augmentedReality\n          globalCustomConfigurator {\n            customExperience\n            __typename\n          }\n          swatches {\n            isSelected\n            itemId\n            label\n            swatchImgUrl\n            url\n            value\n            __typename\n          }\n          totalNumberOfOptions\n          hidePrice\n          ecoRebate\n          quantityLimit\n          categoryHierarchy\n          sskMin\n          sskMax\n          unitOfMeasureCoverage\n          wasMaxPriceRange\n          wasMinPriceRange\n          __typename\n        }\n        identifiers {\n          canonicalUrl\n          productType\n          productLabel\n          modelNumber\n          storeSkuNumber\n          itemId\n          brandName\n          parentId\n          __typename\n        }\n        media {\n          images {\n            url\n            type\n            subType\n            sizes\n            __typename\n          }\n          __typename\n        }\n        dataSource\n        details {\n          collection {\n            name\n            url\n            __typename\n          }\n          __typename\n        }\n        pricing(storeId: $storeId) {\n          alternatePriceDisplay\n          alternate {\n            bulk {\n              pricePerUnit\n              thresholdQuantity\n              value\n              __typename\n            }\n            unit {\n              caseUnitOfMeasure\n              unitsOriginalPrice\n              unitsPerCase\n              value\n              __typename\n            }\n            __typename\n          }\n          original\n          mapAboveOriginalPrice\n          message\n          preferredPriceFlag\n          promotion {\n            type\n            description {\n              shortDesc\n              longDesc\n              __typename\n            }\n            dollarOff\n            percentageOff\n            promotionTag\n            savingsCenter\n            savingsCenterPromos\n            specialBuySavings\n            specialBuyDollarOff\n            specialBuyPercentageOff\n            __typename\n          }\n          specialBuy\n          unitOfMeasure\n          value\n          __typename\n        }\n        taxonomy {\n          breadCrumbs {\n            label\n            __typename\n          }\n          __typename\n        }\n        reviews {\n          ratingsReviews {\n            averageRating\n            totalReviews\n            __typename\n          }\n          __typename\n        }\n        __typename\n      }\n      metadata {\n        zone\n        zoneTitle\n        __typename\n      }\n      __typename\n    }\n    partialTemplates\n    dimensions {\n      label\n      refinements {\n        refinementKey\n        url\n        label\n        recordCount\n        selected\n        imgUrl\n        nestedRefinements {\n          label\n          url\n          recordCount\n          refinementKey\n          __typename\n        }\n        __typename\n      }\n      collapse\n      dimensionId\n      isVisualNav\n      isVisualDimension\n      isNumericFilter\n      isColorSwatch\n      nestedRefinementsLimit\n      visualNavSequence\n      __typename\n    }\n    orangeGraph {\n      universalSearchArray {\n        pods {\n          title\n          description\n          imageUrl\n          link\n          isProContent\n          recordType\n          __typename\n        }\n        info {\n          title\n          __typename\n        }\n        __typename\n      }\n      productTypes\n      __typename\n    }\n    appliedDimensions {\n      label\n      refinements {\n        label\n        refinementKey\n        url\n        __typename\n      }\n      isNumericFilter\n      __typename\n    }\n    primaryFilters {\n      collapse\n      dimensionId\n      isVisualNav\n      isVisualDimension\n      isNumericFilter\n      isColorSwatch\n      label\n      nestedRefinementsLimit\n      refinements {\n        label\n        refinementKey\n        recordCount\n        selected\n        imgUrl\n        url\n        nestedRefinements {\n          label\n          url\n          recordCount\n          refinementKey\n          __typename\n        }\n        __typename\n      }\n      visualNavSequence\n      __typename\n    }\n    buyitagain(dataSource: $dataSource) @skip(if: $skipBuyitagain) {\n      itemId\n      dataSources\n      badges(storeId: $storeId) {\n        name\n        __typename\n      }\n      info {\n        isSponsored\n        sponsoredMetadata {\n          campaignId\n          placementId\n          slotId\n          sponsoredId\n          trackSource\n          __typename\n        }\n        sponsoredBeacon {\n          onClickBeacon\n          onViewBeacon\n          onClickBeacons\n          onViewBeacons\n          __typename\n        }\n        productSubType {\n          name\n          link\n          __typename\n        }\n        augmentedReality\n        globalCustomConfigurator {\n          customExperience\n          __typename\n        }\n        customerSignal {\n          previouslyPurchased\n          __typename\n        }\n        isBuryProduct\n        isGenericProduct\n        returnable\n        hidePrice\n        ecoRebate\n        quantityLimit\n        categoryHierarchy\n        sskMin\n        sskMax\n        unitOfMeasureCoverage\n        wasMaxPriceRange\n        wasMinPriceRange\n        __typename\n      }\n      identifiers {\n        canonicalUrl\n        productType\n        productLabel\n        modelNumber\n        storeSkuNumber\n        itemId\n        brandName\n        specialOrderSku\n        __typename\n      }\n      media {\n        images {\n          url\n          type\n          subType\n          sizes\n          __typename\n        }\n        __typename\n      }\n      details {\n        installation {\n          serviceType\n          __typename\n        }\n        collection {\n          name\n          url\n          __typename\n        }\n        __typename\n      }\n      fulfillment(storeId: $storeId, zipCode: $zipCode) {\n        anchorStoreStatus\n        anchorStoreStatusType\n        backordered\n        backorderedShipDate\n        bossExcludedShipStates\n        excludedShipStates\n        seasonStatusEligible\n        fulfillmentOptions {\n          type\n          fulfillable\n          services {\n            deliveryTimeline\n            deliveryDates {\n              startDate\n              endDate\n              __typename\n            }\n            deliveryCharge\n            dynamicEta {\n              hours\n              minutes\n              __typename\n            }\n            hasFreeShipping\n            freeDeliveryThreshold\n            locations {\n              curbsidePickupFlag\n              isBuyInStoreCheckNearBy\n              distance\n              inventory {\n                isOutOfStock\n                isInStock\n                isLimitedQuantity\n                isUnavailable\n                quantity\n                maxAllowedBopisQty\n                minAllowedBopisQty\n                __typename\n              }\n              isAnchor\n              locationId\n              state\n              storeName\n              storePhone\n              type\n              __typename\n            }\n            type\n            totalCharge\n            __typename\n          }\n          __typename\n        }\n        onlineStoreStatus\n        onlineStoreStatusType\n        __typename\n      }\n      installServices(storeId: $storeId, zipCode: $zipCode) @skip(if: $skipInstallServices) {\n        scheduleAMeasure\n        gccCarpetDesignAndOrderEligible\n        __typename\n      }\n      taxonomy {\n        breadCrumbs {\n          label\n          __typename\n        }\n        __typename\n      }\n      pricing(storeId: $storeId) {\n        alternatePriceDisplay\n        alternate {\n          bulk {\n            pricePerUnit\n            thresholdQuantity\n            value\n            __typename\n          }\n          unit {\n            caseUnitOfMeasure\n            unitsOriginalPrice\n            unitsPerCase\n            value\n            __typename\n          }\n          __typename\n        }\n        original\n        mapAboveOriginalPrice\n        message\n        preferredPriceFlag\n        promotion {\n          type\n          description {\n            shortDesc\n            longDesc\n            __typename\n          }\n          dollarOff\n          percentageOff\n          promotionTag\n          savingsCenter\n          savingsCenterPromos\n          specialBuySavings\n          specialBuyDollarOff\n          specialBuyPercentageOff\n          __typename\n        }\n        specialBuy\n        unitOfMeasure\n        value\n        __typename\n      }\n      dataSource\n      __typename\n    }\n    __typename\n  }\n}"}

# %%
import requests

# %%
session = requests.Session()
response = session.post(url, json=payload, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"data":{"searchModel":{"metadata":{"hasPLPBanner":false,"categoryID":"894d933d-7276-4743-87ea-7becf3bd9838","analytics":{"semanticTokens":"120e00r00e220c1000001e_202409181712161499889820346_us-central1-qjwp 120e00r00e220c1000001e > nf:{4942}:nf ca:{585354}:ca","dynamicLCA":null,"__typename":"Analytics"},"canonicalUrl":"/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/N-5yc1vZcjnu","searchRedirect":null,"clearAllRefinementsURL":"/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/N-5yc1vZcjnu","contentType":"plppage","h1Tag":"Ceiling Fans With Lights","isStoreDisplay":"false","productCount":{"inStore":"80","__typename":"ProductCount"},"stores":{"storeId":"687","storeName":"Upland","address":{"postalCode":"91786","__typename":"Address"},"nearByStores":[{"storeId":"1083","storeName":"North Upland","distance":"3.6716795743623027","address":{"postalCode":"91784","__typename":"Address"},"__typename":"StoreDetails"},{"storeId":"6884","storeName":"Ontario","distance":"4.981315589974254","address":{"postalCode":"91762","__typename":"Address"},"__typename":"StoreDetails"},{"storeId":"6645","storeName":"Pomona","distance":"6.34011334506656","address":{"postalCode":"91766","__typename":"Address"},"__typename":"StoreDetails"},{"storeId":"645","storeName":"Rancho Cucamonga","distance":"7.053247963580094","address":{"postalCode":"91730","__typename":"Address"},"__typename":"StoreDetails"}],"__typename":"StoreDetailsWithNearByStores"},"__typename":"SearchMetadata"},"id":"1215970981","searchReport":{"totalProducts":4942,"didYouMean":null,"correctedKeyword":null,"keyword":null,"pageSize":55,"searchUrl":"","sortBy":"topsellers","sortOrder":"desc","startIndex":96,"__typename":"SearchReport"},"relatedResults":{"universalSearch":null,"relatedServices":[],"visualNavs":[{"label":"Flush Mount","imageId":"dd83aeb8-ca01-43a4-9fef-7acad84f50d8","webUrl":"/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/Flush-Mount/N-5yc1vZcjnuZ1z17veu","categoryId":"585354+4295145414","imageURL":null,"__typename":"VisualNav"},{"label":"Garage","imageId":"674f1251-f48c-4836-83d0-b7d6f8d1a047","webUrl":"/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/Garage/N-5yc1vZcjnuZ1z1ygzb","categoryId":"585354+4296386423","imageURL":null,"__typename":"VisualNav"},{"label":"HINKLEY","imageId":"933dca30-4b27-593f-b9b5-3570f3157020","webUrl":"/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/HINKLEY/N-5yc1vZcjnuZreu","categoryId":"585354+35526","imageURL":null,"__typename":"VisualNav"},{"label":"Hampton Bay","imageId":"d29646af-351e-4a23-b50c-cfaeca16ac0c","webUrl":"/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/Hampton-Bay/N-5yc1vZcjnuZp4","categoryId":"585354+904","imageURL":null,"__typename":"VisualNav"},{"label":"Hunter","imageId":"bda633a8-6779-42a3-bc9f-2592e1ced229","webUrl":"/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/Hunter/N-5yc1vZcjnuZra","categoryId":"585354+982","imageURL":null,"__typename":"VisualNav"},{"label":"Indoor","imageId":"73dd0a32-cc9c-438c-bb8f-ce34b0605d3a","webUrl":"/b/Lighting-Ceiling-Fans-Ceiling-Fans-With-Lights/Indoor/N-5yc1vZcjnuZ1z17lgm","categoryId":"585354+4295132518","imageURL":null,"__typename":"VisualNav"}],"visualNavContainsEvents":false,"relatedKeywords":[],"__typename":"RelatedResults"},"products":[{"itemId":"313725557","dataSources":"searchNav","identifiers":{"canonicalUrl":"/p/KICHLER-Volos-48-in-Indoor-Matte-White-Low-Profile-Ceiling-Fan-with-Integrated-LED-with-Wall-Control-Included-300032MWH/313725557","brandName":"KICHLER","itemId":"313725557","productLabel":"Volos 48 in. Indoor Matte White Low Profile Ceiling Fan with Integrated LED with Wall Control Included","productType":"MERCHANDISE","specialOrderSku":null,"storeSkuNumber":null,"isSuperSku":true,"parentId":"313798375","sampleId":null,"modelNumber":"300032MWH","__typename":"Identifiers"},"media":{"images":[{"url":"https://images.thdstatic.com/productImages/59c72556-08c9-4a71-bd68-c0afa2aa006b/svn/kichler-ceiling-fans-with-lights-300032mwh-64_<SIZE>.jpg","type":"IMAGE","subTy ...

# %%
data = response.json().get('data', {}).get('searchModel', {}).get('products', {})

# %%
data.get()

# %%
def extract_data(product):

    itemId = product.get('itemId', {})
    canonicalUrl = product.get('identifiers', {}).get('canonicalUrl', {})
    brandName = product.get('identifiers', {}).get('brandName', {})
    productLabel = product.get('identifiers', {}).get('productLabel', {})
    storeSkuNumber = product.get('identifiers', {}).get('storeSkuNumber', {})
    parentId = product.get('identifiers', {}).get('parentId', {})
    modelNumber = product.get('identifiers', {}).get('modelNumber', {})
    price = product.get('pricing', {}).get('value', {})
    original_price = product.get('pricing', {}).get('original', {})

    

    averageRating = product.get('reviews', {}).get('ratingsReviews', {}).get('averageRating', {})
    totalReviews = product.get('reviews', {}).get('ratingsReviews', {}).get('totalReviews', {})

    try:
        pickup_inventory = product.get('fulfillment', {}).get('fulfillmentOptions', {})[1].get('services', {})[0].get('locations', {})[0].get('inventory', {}).get('quantity', {})
    except:
        pickup_inventory = None

    try: 
        delivery_inventory = product

    try:
        label = product.get('badges', {})[0].get('label', {})
    except:
        label = None
        
    result = {
        'label': label,
        'itemId': itemId,
        'canonicalUrl':canonicalUrl,
        'brandName':brandName,
        'productLabel':productLabel,
        'storeSkuNumber': storeSkuNumber,
        'parentId': parentId,
        'modelNumber': modelNumber,
        'price': price,
        'original_price': original_price,
        'averageRating': averageRating,
        'totalReviews': totalReviews,
        'inventory': inventory

    }

    return result
# Out:
#   Cell In[23], line 26
#     try:
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
results = []
for product in data:
    results.append(extract_data(product))

# %%
product = data[2]
product.get('badges', {})
# Out:
# [{'name': 'seasonal', 'label': 'New This Season', '__typename': 'Badge'}]

# %%
results
# Out:
# [{'label': None,
#   'itemId': '322897617',
#   'canonicalUrl': '/p/ANTOINE-20-in-LED-Indoor-White-Ceiling-Fan-with-Dimmable-Lighting-Low-Profile-Flush-Mount-Ceiling-Fan-with-Remote-HD-FSD-32/322897617',
#   'brandName': 'ANTOINE',
#   'productLabel': '20 in. LED Indoor White Ceiling Fan with Dimmable Lighting Low Profile Flush Mount Ceiling Fan with Remote',
#   'storeSkuNumber': '1008661901',
#   'parentId': '329147887',
#   'modelNumber': 'HD-FSD-32',
#   'price': 99.99,
#   'original_price': 99.99,
#   'averageRating': '4.2258',
#   'totalReviews': '217',
#   'inventory': 957},
#  {'label': None,
#   'itemId': '206890749',
#   'canonicalUrl': '/p/Big-Ass-Fans-Haiku-52-in-L-Indoor-Black-Ceiling-Fan-with-Integrated-LED-with-Light-Works-with-Alexa-and-Remote-Control-Included-FR127C-U1H00-3L02-09258-258P610/206890749',
#   'brandName': 'Big Ass Fans',
#   'productLabel': 'Haiku 52 in. L Indoor Black Ceiling Fan with Integrated LED with Light Works with Alexa and Remote Control Included',
#   'storeSkuNumber': '1001733572',
#   'parentId': '206890749',
#   'modelNumber': 'FR127C-U1H00-3L02-09258-258P610',
#   'price': 800.0,
#   'original_price': 800.0,
#   'averageRating': '4.3976',
#   'totalReviews': '83',
#   'inventory': 139},
#  {'label': 'New This Season',
#   'itemId': '327982555',
#   'canonicalUrl': '/p/Bell-Howell-15-7-in-Indoor-Matte-Black-LED-Socket-Ceiling-Fan-with-Remote-2299QPH/327982555',
#   'brandName': 'Bell + Howell',
#   'productLabel': '15.7 in. Indoor Matte Black LED Socket Ceiling Fan with Remote',
#   'storeSkuNumber': '1010552002',
#   'parentId': '327982555',
#   'modelNumber': '2299QPH',
#   'price': 49.97,
#   'original_price': 49.97,
#   'averageRating': '4.5987',
#   'totalReviews': '152',
#   'inventory': 359},
#  {'label': 'New This Season',
#   'itemId': '328398102',
#   'canonicalUrl': '/p/MODERN-HABITAT-WhisperBloom-52-in-Indoor-Black-Ceiling-Fan-with-LED-Light-Bulbs-and-Remote-Control-CFL-1891-5252BL/328398102',
#   'brandName': 'MODERN HABITAT',
#   'productLabel': 'WhisperBloom 52 in. Indoor Black Ceiling Fan with LED Light Bulbs and Remote Control',
#   'storeSkuNumber': '1010822840',
#   'parentId': '328886787',
#   'modelNumber': 'CFL-1891-5252BL',
#   'price': 145.0,
#   'original_price': 179.0,
#   'averageRating': '4.6842',
#   'totalReviews': '19',
#   'inventory': 292},
#  {'label': 'New This Season',
#   'itemId': '328430818',
#   'canonicalUrl': '/p/MODERN-HABITAT-AuraVista-52-in-Indoor-Black-Modern-Medium-Red-Oak-Ceiling-Fan-with-LED-Light-Bulbs-and-Remote-Control-CFL-1891-5252RB/328430818',
#   'brandName': 'MODERN HABITAT',
#   'productLabel': 'AuraVista 52 in. Indoor Black Modern Medium Red Oak Ceiling Fan with LED Light Bulbs and Remote Control',
#   'storeSkuNumber': '1010822852',
#   'parentId': '328886960',
#   'modelNumber': 'CFL-1891-5252RB',
#   'price': 139.0,
#   'original_price': 179.0,
#   'averageRating': '4.0741',
#   'totalReviews': '27',
#   'inventory': 196},
#  {'label': None,
#   'itemId': '316889938',
#   'canonicalUrl': '/p/MINKA-AIRE-Light-Wave-44-in-LED-Indoor-Distressed-Koa-Ceiling-Fan-with-Light-and-Remote-Control-F845-DK/316889938',
#   'brandName': 'MINKA-AIRE',
#   'productLabel': 'Light Wave 44 in. LED Indoor Distressed Koa Ceiling Fan with Light and Remote Control',
#   'storeSkuNumber': '1006359061',
#   'parentId': '316913178',
#   'modelNumber': 'F845-DK',
#   'price': 269.95,
#   'original_price': 269.95,
#   'averageRating': '4.2824',
#   'totalReviews': '85',
#   'inventory': 5},
#  {'label': 'Exclusive',
#   'itemId': '321770262',
#   'canonicalUrl': '/p/Home-Decorators-Collection-Makenna-52-in-White-Color-Changing-Integrated-Indoor-LED-Matte-Black-Smart-Hubspace-Ceiling-Fan-with-Light-and-Remote-56235/321770262',
#   'brandName': 'Home Decorators Collection',
#   'productLabel': 'Makenna 52 in. White Color Changing Integrated Indoor LED Matte Black Smart Hubspace Ceiling Fan with Light and Remote',
#   'storeSkuNumber': '1008271600',
#   'parentId': '324614678',
#   'modelNumber': '56235',
#   'price': 199.0,
#   'original_price': 199.0,
#   'averageRating': '4.0',
#   'totalReviews': '7',
#   'inventory': 91},
#  {'label': 'New This Season',
#   'itemId': '329480062',
#   'canonicalUrl': '/p/Artika-Groove-20-in-Indoor-Black-8-Steps-CCT-11-42-in-Integrated-LED-Ceiling-Fan-with-Remote-Included-FAN-GRR-HD2BL/329480062',
#   'brandName': 'Artika',
#   'productLabel': 'Groove 20 in. Indoor Black 8 Steps CCT 11.42 in. Integrated LED Ceiling Fan with Remote Included',
#   'storeSkuNumber': '1011373999',
#   'parentId': '329480062',
#   'modelNumber': 'FAN-GRR-HD2BL',
#   'price': 199.0,
#   'original_price': 199.0,
#   'averageRating': '4.6',
#   'totalReviews': '10',
#   'inventory': 23},
#  {'label': 'New This Season',
#   'itemId': '329445439',
#   'canonicalUrl': '/p/Artika-Aiden-24-in-Indoor-Black-8-Steps-CCT-17-7-in-Integrated-LED-Ceiling-Fan-with-Remote-Included-FAN-AIR-HD2BL/329445439',
#   'brandName': 'Artika',
#   'productLabel': 'Aiden 24 in. Indoor Black 8 Steps CCT 17.7 in. Integrated LED Ceiling Fan with Remote Included',
#   'storeSkuNumber': '1011373998',
#   'parentId': '329445439',
#   'modelNumber': 'FAN-AIR-HD2BL',
#   'price': 199.0,
#   'original_price': 199.0,
#   'averageRating': '4.4444',
#   'totalReviews': '9',
#   'inventory': 10},
#  {'label': 'Exclusive',
#   'itemId': '322700723',
#   'canonicalUrl': '/p/Hampton-Bay-Nevali-52-in-White-Changing-LED-Indoor-Smart-Hubspace-Ceiling-Fan-with-Light-and-Remote-Control-Included-92394/322700723',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Nevali 52 in. White Changing LED Indoor Smart Hubspace Ceiling Fan with Light and Remote Control Included',
#   'storeSkuNumber': '1008631292',
#   'parentId': '322700723',
#   'modelNumber': '92394',
#   'price': 179.0,
#   'original_price': 179.0,
#   'averageRating': '4.0755',
#   'totalReviews': '53',
#   'inventory': 0},
#  {'label': None,
#   'itemId': '300937520',
#   'canonicalUrl': '/p/Hampton-Bay-Glendale-42-in-LED-Indoor-White-Ceiling-Fan-with-Light-Kit-AM212-WH/300937520',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Glendale 42 in. LED Indoor White Ceiling Fan with Light Kit',
#   'storeSkuNumber': '1000044891',
#   'parentId': '302368716',
#   'modelNumber': 'AM212-WH',
#   'price': 69.97,
#   'original_price': 69.97,
#   'averageRating': '4.4943',
#   'totalReviews': '3334',
#   'inventory': 0},
#  {'label': None,
#   'itemId': '318475105',
#   'canonicalUrl': '/p/CARRO-Brently-52-in-Dimmable-LED-Indoor-Outdoor-White-Smart-Ceiling-Fan-with-Light-and-Remote-Works-with-Alexa-Google-Home-NS523B-L12-W1/318475105',
#   'brandName': 'CARRO',
#   'productLabel': 'Brently 52 in. Dimmable LED Indoor/Outdoor White Smart Ceiling Fan with Light and Remote, Works with Alexa/Google Home',
#   'storeSkuNumber': '1006795410',
#   'parentId': '318475100',
#   'modelNumber': 'NS523B-L12-W1',
#   'price': 139.99,
#   'original_price': 336.0,
#   'averageRating': '4.15',
#   'totalReviews': '20',
#   'inventory': 58},
#  {'label': 'Top Rated',
#   'itemId': '313725557',
#   'canonicalUrl': '/p/KICHLER-Volos-48-in-Indoor-Matte-White-Low-Profile-Ceiling-Fan-with-Integrated-LED-with-Wall-Control-Included-300032MWH/313725557',
#   'brandName': 'KICHLER',
#   'productLabel': 'Volos 48 in. Indoor Matte White Low Profile Ceiling Fan with Integrated LED with Wall Control Included',
#   'storeSkuNumber': None,
#   'parentId': '313798375',
#   'modelNumber': '300032MWH',
#   'price': 217.46,
#   'original_price': 217.46,
#   'averageRating': '4.4118',
#   'totalReviews': '102',
#   'inventory': 1194},
#  {'label': 'Top Rated',
#   'itemId': '318749133',
#   'canonicalUrl': '/p/Hampton-Bay-Hawkins-III-44-in-LED-Indoor-Brushed-Nickel-Flush-Mount-Ceiling-Fan-with-Light-YG204D-BN/318749133',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Hawkins III 44 in. LED Indoor Brushed Nickel Flush Mount Ceiling Fan with Light',
#   'storeSkuNumber': '1006878798',
#   'parentId': '322436831',
#   'modelNumber': 'YG204D-BN',
#   'price': 84.97,
#   'original_price': 84.97,
#   'averageRating': '4.0429',
#   'totalReviews': '163',
#   'inventory': 2},
#  {'label': None,
#   'itemId': '322702565',
#   'canonicalUrl': '/p/Hampton-Bay-Ashby-Park-52-in-White-Color-Changing-Integrated-LED-Matte-White-Indoor-Ceiling-Fan-with-Light-Kit-and-Remote-Control-59258/322702565',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Ashby Park 52 in. White Color Changing Integrated LED Matte White Indoor Ceiling Fan with Light Kit and Remote Control',
#   'storeSkuNumber': '1008503137',
#   'parentId': '316938274',
#   'modelNumber': '59258',
#   'price': 164.0,
#   'original_price': 164.0,
#   'averageRating': '4.4615',
#   'totalReviews': '182',
#   'inventory': 135},
#  {'label': None,
#   'itemId': '323360590',
#   'canonicalUrl': '/p/Sofucor-52-in-Integrated-LED-Indoor-Outdoor-White-Ceiling-Fan-with-Light-Kit-and-Remote-Control-KBSYL52K012WH/323360590',
#   'brandName': 'Sofucor',
#   'productLabel': '52 in. Integrated LED Indoor/Outdoor White Ceiling Fan with Light Kit and Remote Control',
#   'storeSkuNumber': '1008783634',
#   'parentId': '322714760',
#   'modelNumber': 'KBSYL52K012WH',
#   'price': 215.99,
#   'original_price': 317.0,
#   'averageRating': '4.1707',
#   'totalReviews': '41',
#   'inventory': 104},
#  {'label': None,
#   'itemId': '321448024',
#   'canonicalUrl': '/p/ANTOINE-16-in-Indoor-Smoky-Gray-Low-Profile-Ceiling-Fan-with-Dimmable-LED-Light-Flush-Mount-Bedroom-Ceiling-Fan-with-Remote-HD-FSD-15/321448024',
#   'brandName': 'ANTOINE',
#   'productLabel': '16 in. Indoor Smoky Gray Low Profile Ceiling Fan with Dimmable LED Light Flush Mount Bedroom Ceiling Fan with Remote',
#   'storeSkuNumber': '1008175016',
#   'parentId': '321448024',
#   'modelNumber': 'HD-FSD-15',
#   'price': 195.95,
#   'original_price': 195.95,
#   'averageRating': '3.5517',
#   'totalReviews': '116',
#   'inventory': 989},
#  {'label': None,
#   'itemId': '315373050',
#   'canonicalUrl': '/p/matrix-decor-52-in-Indoor-Chrome-Crystal-Chandelier-Ceiling-Fan-with-Light-and-Remote-Control-MD-F6217110V/315373050',
#   'brandName': 'matrix decor',
#   'productLabel': '52 in. Indoor Chrome Crystal Chandelier Ceiling Fan with Light and Remote Control',
#   'storeSkuNumber': '1005943405',
#   'parentId': '319671388',
#   'modelNumber': 'MD-F6217110V',
#   'price': 169.65,
#   'original_price': 169.65,
#   'averageRating': '4.4938',
#   'totalReviews': '322',
#   'inventory': 34},
#  {'label': 'Exclusive',
#   'itemId': '322920432',
#   'canonicalUrl': '/p/Hampton-Bay-Halwin-52-in-Indoor-Outdoor-Matte-Black-Low-Profile-Ceiling-Fan-with-Adjustable-White-LED-with-Remote-Included-AK396H-MBK/322920432',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Halwin 52 in. Indoor/Outdoor Matte Black Low Profile Ceiling Fan with Adjustable White LED with Remote Included',
#   'storeSkuNumber': '1008590305',
#   'parentId': '325225130',
#   'modelNumber': 'AK396H-MBK',
#   'price': 179.0,
#   'original_price': 179.0,
#   'averageRating': '4.3947',
#   'totalReviews': '76',
#   'inventory': 223},
#  {'label': 'Top Rated',
#   'itemId': '314253821',
#   'canonicalUrl': '/p/Home-Decorators-Collection-Windara-22-in-LED-Indoor-Covered-Outdoor-Bronze-Ceiling-Fan-SFL-550L2/314253821',
#   'brandName': 'Home Decorators Collection',
#   'productLabel': 'Windara 22 in. LED Indoor/Covered Outdoor Bronze Ceiling Fan',
#   'storeSkuNumber': '1005742758',
#   'parentId': '316293792',
#   'modelNumber': 'SFL-550L2',
#   'price': 249.0,
#   'original_price': 249.0,
#   'averageRating': '4.0897',
#   'totalReviews': '1750',
#   'inventory': 112},
#  {'label': None,
#   'itemId': '322701653',
#   'canonicalUrl': '/p/Hampton-Bay-Mena-44-in-White-Color-Changing-Integrated-LED-Indoor-Outdoor-Matte-White-Hugger-Ceiling-Fan-with-Light-Kit-and-Remote-92401/322701653',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Mena 44 in. White Color Changing Integrated LED Indoor/Outdoor Matte White Hugger Ceiling Fan with Light Kit and Remote',
#   'storeSkuNumber': '1008654974',
#   'parentId': '331730894',
#   'modelNumber': '92401',
#   'price': 149.0,
#   'original_price': 149.0,
#   'averageRating': '4.8125',
#   'totalReviews': '80',
#   'inventory': 96},
#  {'label': 'New This Season',
#   'itemId': '327900413',
#   'canonicalUrl': '/p/Big-Ass-Fans-Haiku-L-52-in-Dia-Smart-Outdoor-Black-Ceiling-Fan-Integrated-LED-2700K-Universal-Mount-with-5-in-Downrod-FR127C-U1H00-3L07-09258-258P610/327900413',
#   'brandName': 'Big Ass Fans',
#   'productLabel': 'Haiku L - 52 in. Dia, Smart Outdoor Black, Ceiling Fan, Integrated LED 2700K, Universal Mount with 5 in. Downrod',
#   'storeSkuNumber': '1010661878',
#   'parentId': '327854557',
#   'modelNumber': 'FR127C-U1H00-3L07-09258-258P610',
#   'price': 950.0,
#   'original_price': 950.0,
#   'averageRating': '5.0',
#   'totalReviews': '2',
#   'inventory': 13},
#  {'label': None,
#   'itemId': '324685097',
#   'canonicalUrl': '/p/Hunter-Dempsey-44-in-Indoor-Matte-Black-Ceiling-Fan-with-Remote-Control-and-Light-Kit-Included-52390/324685097',
#   'brandName': 'Hunter',
#   'productLabel': 'Dempsey 44 in. Indoor Matte Black Ceiling Fan with Remote Control and Light Kit Included',
#   'storeSkuNumber': '1009314096',
#   'parentId': '325248169',
#   'modelNumber': '52390',
#   'price': 149.99,
#   'original_price': 149.99,
#   'averageRating': '3.9608',
#   'totalReviews': '51',
#   'inventory': 86},
#  {'label': None,
#   'itemId': '319891598',
#   'canonicalUrl': '/p/AIRE-BY-MINKA-Hillsdale-65-in-Integrated-LED-Indoor-Outdoor-Coal-Ceiling-Fan-with-Light-Kit-and-Remote-Control-04755/319891598',
#   'brandName': 'AIRE BY MINKA',
#   'productLabel': 'Hillsdale 65 in. Integrated LED Indoor/Outdoor Coal Ceiling Fan with Light Kit and Remote Control',
#   'storeSkuNumber': '1007716766',
#   'parentId': '319891598',
#   'modelNumber': '04755',
#   'price': 289.0,
#   'original_price': 289.0,
#   'averageRating': '4.0',
#   'totalReviews': '14',
#   'inventory': 19},
#  {'label': None,
#   'itemId': '310172695',
#   'canonicalUrl': '/p/MINKA-AIRE-Concept-II-44-in-Integrated-LED-Indoor-White-Ceiling-Fan-with-Light-with-Remote-Control-F518L-WH/310172695',
#   'brandName': 'MINKA-AIRE',
#   'productLabel': 'Concept II 44 in. Integrated LED Indoor White Ceiling Fan with Light with Remote Control',
#   'storeSkuNumber': '1004485431',
#   'parentId': '324829621',
#   'modelNumber': 'F518L-WH',
#   'price': 364.95,
#   'original_price': 364.95,
#   'averageRating': '4.5307',
#   'totalReviews': '309',
#   'inventory': 28},
#  {'label': None,
#   'itemId': '322567707',
#   'canonicalUrl': '/p/ANTOINE-20-in-4-Light-Indoor-Black-Wood-Grain-Industrial-Metal-Cage-Enclosed-Ceiling-Fan-with-Light-Kit-and-Remote-HD-LZ-01/322567707',
#   'brandName': 'ANTOINE',
#   'productLabel': '20 in. 4-Light Indoor Black Wood Grain Industrial Metal Cage Enclosed Ceiling Fan with Light Kit and Remote',
#   'storeSkuNumber': '1008661777',
#   'parentId': '322567707',
#   'modelNumber': 'HD-LZ-01',
#   'price': 130.14,
#   'original_price': 130.14,
#   'averageRating': '4.6897',
#   'totalReviews': '58',
#   'inventory': 891},
#  {'label': 'Exclusive',
#   'itemId': '322920436',
#   'canonicalUrl': '/p/Hampton-Bay-Ceva-54-in-Indoor-Outdoor-Matte-Black-with-Matte-Black-Blades-Ceiling-Fan-with-Adjustable-White-with-Remote-Included-AK363HB-MBK/322920436',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Ceva 54 in. Indoor/Outdoor Matte Black with Matte Black Blades Ceiling Fan with Adjustable White with Remote Included',
#   'storeSkuNumber': '1008590298',
#   'parentId': '325225129',
#   'modelNumber': 'AK363HB-MBK',
#   'price': 179.0,
#   'original_price': 179.0,
#   'averageRating': '4.75',
#   'totalReviews': '36',
#   'inventory': 39},
#  {'label': None,
#   'itemId': '322715131',
#   'canonicalUrl': '/p/Sofucor-52-in-Integrated-LED-Indoor-Outdoor-Black-Ceiling-Fan-with-Light-Kit-and-Remote-Control-KBS0852K012BK/322715131',
#   'brandName': 'Sofucor',
#   'productLabel': '52 in. Integrated LED Indoor/Outdoor Black Ceiling Fan with Light Kit and Remote Control',
#   'storeSkuNumber': '1008661815',
#   'parentId': '322714760',
#   'modelNumber': 'KBS0852K012BK',
#   'price': 215.99,
#   'original_price': 317.0,
#   'averageRating': '4.1707',
#   'totalReviews': '41',
#   'inventory': 278},
#  {'label': 'Top Rated',
#   'itemId': '206648787',
#   'canonicalUrl': '/p/Home-Decorators-Collection-Trudeau-60-in-LED-Indoor-Espresso-Bronze-Ceiling-Fan-with-Light-Kit-and-Remote-Control-YG545-EB/206648787',
#   'brandName': 'Home Decorators Collection',
#   'productLabel': 'Trudeau 60 in. LED Indoor Espresso Bronze Ceiling Fan with Light Kit and Remote Control',
#   'storeSkuNumber': '1001693781',
#   'parentId': '302368734',
#   'modelNumber': 'YG545-EB',
#   'price': 429.0,
#   'original_price': 429.0,
#   'averageRating': '4.2785',
#   'totalReviews': '754',
#   'inventory': 296},
#  {'label': 'Exclusive',
#   'itemId': '308027653',
#   'canonicalUrl': '/p/Hunter-Oakhurst-II-52-in-Low-Profile-LED-Indoor-Fresh-White-Ceiling-Fan-with-Light-Kit-52302/308027653',
#   'brandName': 'Hunter',
#   'productLabel': 'Oakhurst II 52 in. Low Profile LED Indoor Fresh White Ceiling Fan with Light Kit',
#   'storeSkuNumber': '1004605565',
#   'parentId': '312187462',
#   'modelNumber': '52302',
#   'price': 119.0,
#   'original_price': 119.0,
#   'averageRating': '0.000000',
#   'totalReviews': None,
#   'inventory': 257},
#  {'label': None,
#   'itemId': '325858811',
#   'canonicalUrl': '/p/FANNEHONNE-Lidia-19-68-in-Indoor-Modern-White-Crystal-Flush-Mount-Ceiling-Fan-with-Light-White-LED-Ceiling-Fan-for-Bedroom-CA000110202/325858811',
#   'brandName': 'FANNEHONNE',
#   'productLabel': 'Lidia 19.68 in Indoor Modern White Crystal Flush Mount Ceiling Fan with Light, White LED Ceiling Fan for Bedroom',
#   'storeSkuNumber': '1009742396',
#   'parentId': '328254613',
#   'modelNumber': 'CA000110202',
#   'price': 109.99,
#   'original_price': 133.33,
#   'averageRating': '4.6491',
#   'totalReviews': '57',
#   'inventory': 1115},
#  {'label': 'New This Season',
#   'itemId': '329310904',
#   'canonicalUrl': '/p/Parrot-Uncle-60-in-Indoor-Color-Changing-Integrated-LED-Matte-Black-Ceiling-Fan-with-Light-and-Remote-Control-F8310110V/329310904',
#   'brandName': 'Parrot Uncle',
#   'productLabel': '60 in. Indoor Color Changing Integrated LED Matte Black Ceiling Fan with Light and Remote Control',
#   'storeSkuNumber': '1011059570',
#   'parentId': '331494035',
#   'modelNumber': 'F8310110V',
#   'price': 169.0,
#   'original_price': 199.98,
#   'averageRating': '4.9091',
#   'totalReviews': '11',
#   'inventory': 173},
#  {'label': None,
#   'itemId': '321407208',
#   'canonicalUrl': '/p/ANTOINE-20-in-Black-Low-Profile-Flush-Mount-LED-with-Remote-and-APP-Smart-Control-Indoor-Ceiling-Fan-with-Dimmable-Lighting-HD-FSD-14/321407208',
#   'brandName': 'ANTOINE',
#   'productLabel': '20 in. Black Low Profile Flush Mount LED with Remote and APP Smart Control Indoor Ceiling Fan with Dimmable Lighting',
#   'storeSkuNumber': '1008193833',
#   'parentId': '332536820',
#   'modelNumber': 'HD-FSD-14',
#   'price': 102.96,
#   'original_price': 167.79,
#   'averageRating': '4.1667',
#   'totalReviews': '120',
#   'inventory': 810},
#  {'label': 'Exclusive',
#   'itemId': '300654438',
#   'canonicalUrl': '/p/Hampton-Bay-Holly-Springs-52-in-LED-Indoor-Brushed-Nickel-Ceiling-Fan-with-Light-Kit-57269/300654438',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Holly Springs 52 in. LED Indoor Brushed Nickel Ceiling Fan with Light Kit',
#   'storeSkuNumber': '1002263777',
#   'parentId': '328388725',
#   'modelNumber': '57269',
#   'price': 79.97,
#   'original_price': 79.97,
#   'averageRating': '4.6189',
#   'totalReviews': '963',
#   'inventory': 23},
#  {'label': None,
#   'itemId': '318630516',
#   'canonicalUrl': '/p/CARRO-Essex-52-in-Integrated-LED-Indoor-Outdoor-Black-Smart-Ceiling-Fan-with-Light-and-Remote-Works-w-Alexa-Google-Home-S525J-L12-B5-1/318630516',
#   'brandName': 'CARRO',
#   'productLabel': 'Essex 52 in. Integrated LED Indoor/Outdoor Black Smart Ceiling Fan with Light and Remote, Works w/Alexa/Google Home',
#   'storeSkuNumber': '1006880642',
#   'parentId': '319873391',
#   'modelNumber': 'S525J-L12-B5-1',
#   'price': 149.99,
#   'original_price': 299.0,
#   'averageRating': '3.3939',
#   'totalReviews': '33',
#   'inventory': 840},
#  {'label': 'Exclusive',
#   'itemId': '314459948',
#   'canonicalUrl': '/p/Hampton-Bay-Norwood-52-in-Indoor-Outdoor-LED-Matte-Black-Damp-Rated-Downrod-Ceiling-Fan-with-Light-Kit-and-5-Reversible-Blades-52129/314459948',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Norwood 52 in. Indoor/Outdoor LED Matte Black Damp Rated Downrod Ceiling Fan with Light Kit and 5 Reversible Blades',
#   'storeSkuNumber': '1005819959',
#   'parentId': '314459948',
#   'modelNumber': '52129',
#   'price': 139.0,
#   'original_price': 139.0,
#   'averageRating': '4.6353',
#   'totalReviews': '85',
#   'inventory': 17},
#  {'label': None,
#   'itemId': '325203807',
#   'canonicalUrl': '/p/Breezary-Jemore-52-in-Indoor-Flush-Mounted-Black-Crystal-Ceiling-Fan-with-Light-Kit-and-Remote-Control-Included-BZ24001-ORB-A1/325203807',
#   'brandName': 'Breezary',
#   'productLabel': 'Jemore 52 in. Indoor Flush Mounted Black Crystal Ceiling Fan with Light Kit and Remote Control Included',
#   'storeSkuNumber': '1009527265',
#   'parentId': '325501993',
#   'modelNumber': 'BZ24001-ORB-A1',
#   'price': 149.0,
#   'original_price': 269.6,
#   'averageRating': '4.4333',
#   'totalReviews': '30',
#   'inventory': 43},
#  {'label': 'Exclusive',
#   'itemId': '314966519',
#   'canonicalUrl': '/p/Hunter-Agnew-52-in-LED-Indoor-Brushed-Nickel-Ceiling-Fan-with-Light-and-Remote-51214/314966519',
#   'brandName': 'Hunter',
#   'productLabel': 'Agnew 52 in. LED Indoor Brushed Nickel Ceiling Fan with Light and Remote',
#   'storeSkuNumber': '1005873277',
#   'parentId': '314966519',
#   'modelNumber': '51214',
#   'price': 159.0,
#   'original_price': 159.0,
#   'averageRating': '3.9918',
#   'totalReviews': '122',
#   'inventory': 197},
#  {'label': None,
#   'itemId': '326092784',
#   'canonicalUrl': '/p/ANTOINE-20-in-LED-Indoor-Black-Low-Profile-Ceiling-Fan-with-Dimmable-Lighting-Small-Flush-Mount-Ceiling-Fan-with-Remote-HD-IL-01/326092784',
#   'brandName': 'ANTOINE',
#   'productLabel': '20 in. LED Indoor Black Low Profile Ceiling Fan with Dimmable Lighting Small Flush Mount Ceiling Fan with Remote',
#   'storeSkuNumber': '1009871004',
#   'parentId': '322897589',
#   'modelNumber': 'HD-IL-01',
#   'price': 109.99,
#   'original_price': 156.99,
#   'averageRating': '4.6444',
#   'totalReviews': '45',
#   'inventory': 288},
#  {'label': 'Exclusive',
#   'itemId': '301162046',
#   'canonicalUrl': '/p/Home-Decorators-Collection-Pendersen-42-in-Integrated-LED-Indoor-Outdoor-Espresso-Bronze-Ceiling-Fan-with-Light-Kit-and-Remote-Control-AM348-EB/301162046',
#   'brandName': 'Home Decorators Collection',
#   'productLabel': 'Pendersen 42 in. Integrated LED Indoor/Outdoor Espresso Bronze Ceiling Fan with Light Kit and Remote Control',
#   'storeSkuNumber': '1002498700',
#   'parentId': '304705524',
#   'modelNumber': 'AM348-EB',
#   'price': 273.99,
#   'original_price': 273.99,
#   'averageRating': '3.8031',
#   'totalReviews': '320',
#   'inventory': 68},
#  {'label': 'Exclusive',
#   'itemId': '301161770',
#   'canonicalUrl': '/p/Home-Decorators-Collection-Windward-44-in-LED-Brushed-Nickel-Ceiling-Fan-with-Light-Kit-51565/301161770',
#   'brandName': 'Home Decorators Collection',
#   'productLabel': 'Windward 44 in. LED Brushed Nickel Ceiling Fan with Light Kit',
#   'storeSkuNumber': '1002543110',
#   'parentId': '306536485',
#   'modelNumber': '51565',
#   'price': 129.0,
#   'original_price': 129.0,
#   'averageRating': '4.4642',
#   'totalReviews': '1271',
#   'inventory': 68},
#  {'label': None,
#   'itemId': '323008032',
#   'canonicalUrl': '/p/Hunter-Antero-52-in-Hunter-Express-Indoor-Fresh-White-Ceiling-Fan-with-Light-Kit-Included-52129/323008032',
#   'brandName': 'Hunter',
#   'productLabel': 'Antero 52 in. Hunter Express Indoor Fresh White Ceiling Fan with Light Kit Included',
#   'storeSkuNumber': '1008625018',
#   'parentId': '323008032',
#   'modelNumber': '52129',
#   'price': 149.0,
#   'original_price': 149.0,
#   'averageRating': '4.5498',
#   'totalReviews': '231',
#   'inventory': 54},
#  {'label': None,
#   'itemId': '319979324',
#   'canonicalUrl': '/p/CARRO-Essex-52-in-Dimmable-LED-Indoor-Outdoor-Black-Smart-Ceiling-Fan-with-Light-and-Remote-Works-w-Alexa-Google-Home-HS525J-L12-BO-1/319979324',
#   'brandName': 'CARRO',
#   'productLabel': 'Essex 52 in. Dimmable LED Indoor/Outdoor Black Smart Ceiling Fan with Light and Remote, Works w/Alexa/Google Home',
#   'storeSkuNumber': '1007512387',
#   'parentId': '322224792',
#   'modelNumber': 'HS525J-L12-BO-1',
#   'price': 149.99,
#   'original_price': 299.0,
#   'averageRating': '4.2941',
#   'totalReviews': '17',
#   'inventory': 733},
#  {'label': None,
#   'itemId': '318539622',
#   'canonicalUrl': '/p/ANTOINE-17-in-Indoor-Black-Ceiling-Fan-Farmhouse-Caged-Ceiling-Fan-with-Lights-and-Remote-Enclosed-Ceiling-Fan-FS6643-4/318539622',
#   'brandName': 'ANTOINE',
#   'productLabel': '17 in. Indoor Black Ceiling Fan Farmhouse Caged Ceiling Fan with Lights and Remote Enclosed Ceiling Fan',
#   'storeSkuNumber': '1007080003',
#   'parentId': '318539622',
#   'modelNumber': 'FS6643-4',
#   'price': 119.99,
#   'original_price': 294.99,
#   'averageRating': '4.4186',
#   'totalReviews': '43',
#   'inventory': 581},
#  {'label': None,
#   'itemId': '312743226',
#   'canonicalUrl': '/p/Hampton-Bay-Lodge-52-in-LED-Nutmeg-Ceiling-Fan-with-Light-and-Remote-Control-YG098B-NM/312743226',
#   'brandName': 'Hampton Bay',
#   'productLabel': 'Lodge 52 in. LED Nutmeg Ceiling Fan with Light and Remote Control',
#   'storeSkuNumber': '1005228605',
#   'parentId': '312743226',
#   'modelNumber': 'YG098B-NM',
#   'price': 249.0,
#   'original_price': 249.0,
#   'averageRating': '4.6522',
#   'totalReviews': '46',
#   'inventory': 35},
#  {'label': None,
#   'itemId': '326944132',
#   'canonicalUrl': '/p/Hunter-Betsy-44-in-Indoor-Fresh-White-Ceiling-Fan-with-Light-Kit-Hardware-Included-52765/326944132',
#   'brandName': 'Hunter',
#   'productLabel': 'Betsy 44 in. Indoor Fresh White Ceiling Fan with Light Kit Hardware Included',
#   'storeSkuNumber': '1010212354',
#   'parentId': '332226156',
#   'modelNumber': '52765',
#   'price': 129.0,
#   'original_price': 129.0,
#   'averageRating': '4.1053',
#   'totalReviews': '19',
#   'inventory': 411},
#  {'label': None,
#   'itemId': '319341946',
#   'canonicalUrl': '/p/Hunter-Minimus-52-in-Integrated-LED-Indoor-Matte-Black-Ceiling-Fan-with-Remote-and-Light-Kit-51432/319341946',
#   'brandName': 'Hunter',
#   'productLabel': 'Minimus 52 in. Integrated LED Indoor Matte Black Ceiling Fan with Remote and Light Kit',
#   'storeSkuNumber': '1007173220',
#   'parentId': '320118311',
#   'modelNumber': '51432',
#   'price': 271.97,
#   'original_price': 271.97,
#   'averageRating': '4.0625',
#   'totalReviews': '80',
#   'inventory': 11},
#  {'label': None,
#   'itemId': '318472981',
#   'canonicalUrl': '/p/Hunter-Crown-Canyon-II-52-in-Indoor-Outdoor-Matte-Black-Ceiling-Fan-with-Light-Kit-51593/318472981',
#   'brandName': 'Hunter',
#   'productLabel': 'Crown Canyon II 52 in. Indoor/Outdoor Matte Black Ceiling Fan with Light Kit',
#   'storeSkuNumber': '1006827617',
#   'parentId': '312187460',
#   'modelNumber': '51593',
#   'price': 179.0,
#   'original_price': 179.0,
#   'averageRating': '4.5655',
#   'totalReviews': '168',
#   'inventory': 0},
#  {'label': 'Exclusive',
#   'itemId': '206394978',
#   'canonicalUrl': '/p/Home-Decorators-Collection-Reagan-52-in-LED-Indoor-Brushed-Nickel-Ceiling-Fan-with-Light-Kit-and-Remote-Control-YG423-BN/206394978',
#   'brandName': 'Home Decorators Collection',
#   'productLabel': 'Reagan 52 in. LED Indoor Brushed Nickel Ceiling Fan with Light Kit and Remote Control',
#   'storeSkuNumber': '1001681762',
#   'parentId': '206394978',
#   'modelNumber': 'YG423-BN',
#   'price': 199.0,
#   'original_price': 199.0,
#   'averageRating': '4.2034',
#   'totalReviews': '467',
#   'inventory': 23},
#  {'label': None,
#   'itemId': '320292970',
#   'canonicalUrl': '/p/CARRO-Voyager-52-in-Dimmable-LED-Indoor-Outdoor-Black-Smart-Ceiling-Fan-with-Light-and-Remote-Works-with-Alexa-Google-Home-HS525B-L22-B2-1-FM/320292970',
#   'brandName': 'CARRO',
#   'productLabel': 'Voyager 52 in. Dimmable LED Indoor/Outdoor Black Smart Ceiling Fan with Light and Remote, Works with Alexa/Google Home',
#   'storeSkuNumber': '1007691890',
#   'parentId': '322060267',
#   'modelNumber': 'HS525B-L22-B2-1-FM',
#   'price': 189.0,
#   'original_price': 349.0,
#   'averageRating': '3.9677',
#   'totalReviews': '31',
#   'inventory': 95},
#  {'label': None,
#   'itemId': '325756631',
#   'canonicalUrl': '/p/FANNEHONNE-22-in-LED-Indoor-White-Crystal-Ceiling-Fan-with-Modern-Light-White-Flush-Mount-Fan-for-Bedroom-CA00001103/325756631',
#   'brandName': 'FANNEHONNE',
#   'productLabel': '22 in. LED Indoor White Crystal Ceiling Fan with Modern Light White Flush Mount Fan for Bedroom',
#   'storeSkuNumber': '1009742331',
#   'parentId': '325756631',
#   'modelNumber': 'CA00001103',
#   'price': 172.99,
#   'original_price': 183.33,
#   'averageRating': '4.6923',
#   'totalReviews': '26',
#   'inventory': 365},
#  {'label': 'Top Rated',
#   'itemId': '321505988',
#   'canonicalUrl': '/p/Triplicity-30-in-Indoor-LED-Matte-Black-Ceiling-Fan-with-Light-DB30TMB-LP/321505988',
#   'brandName': None,
#   'productLabel': 'Triplicity 30 in. Indoor LED Matte Black Ceiling Fan with Light',
#   'storeSkuNumber': '1008125155',
#   'parentId': '310141255',
#   'modelNumber': 'DB30TMB-LP',
#   'price': 59.97,
#   'original_price': 59.97,
#   'averageRating': '4.1293',
#   'totalReviews': '410',
#   'inventory': 7},
#  {'label': 'New This Season',
#   'itemId': '331104657',
#   'canonicalUrl': '/p/DREO-44-in-Indoor-Silver-Ceiling-Fan-with-Lights-and-Remote-DR-HCF003S/331104657',
#   'brandName': 'DREO',
#   'productLabel': '44 in. Indoor Silver Ceiling Fan with Lights and Remote',
#   'storeSkuNumber': '1012085961',
#   'parentId': '331104657',
#   'modelNumber': 'DR-HCF003S',
#   'price': 149.99,
#   'original_price': 149.99,
#   'averageRating': '4.9091',
#   'totalReviews': '11',
#   'inventory': 23},
#  {'label': None,
#   'itemId': '327577309',
#   'canonicalUrl': '/p/Sofucor-52-in-Indoor-Outdoor-5-Blades-Black-Downrod-Ceiling-Fan-with-Led-Lights-and-6-Speed-DC-Remote-Morden-Farmhouse-HT-52K096-BKSMW/327577309',
#   'brandName': 'Sofucor',
#   'productLabel': '52 in. Indoor/Outdoor 5 Blades Black Downrod Ceiling Fan with Led Lights and 6 Speed DC Remote-Morden, Farmhouse',
#   'storeSkuNumber': '1010399927',
#   'parentId': '327575405',
#   'modelNumber': 'HT-52K096-BKSMW',
#   'price': 186.23,
#   'original_price': 290.99,
#   'averageRating': '4.1176',
#   'totalReviews': '17',
#   'inventory': 97},
#  {'label': 'New This Season',
#   'itemId': '329464395',
#   'canonicalUrl': '/p/Honeywell-Berryhill-48-in-Color-Changing-LED-Dual-Mount-Matte-Black-Ceiling-Fan-with-3-Reversible-Blades-and-Pull-Chains-51858-07/329464395',
#   'brandName': 'Honeywell',
#   'productLabel': 'Berryhill 48 in. Color Changing LED Dual Mount Matte Black Ceiling Fan with 3 Reversible Blades and Pull Chains',
#   'storeSkuNumber': '1011222865',
#   'parentId': '329462901',
#   'modelNumber': '51858-07',
#   'price': 149.99,
#   'original_price': 149.99,
#   'averageRating': '4.871',
#   'totalReviews': '31',
#   'inventory': 599},
#  {'label': 'New This Season',
#   'itemId': '330457976',
#   'canonicalUrl': '/p/HINNIXY-2-Pack-52-in-Indoor-Matte-Black-3-Colors-LED-Ceiling-Fan-with-Dual-Finish-Blades-and-Light-Kit-and-Remote-control-Y23FSD0019-4802HD/330457976',
#   'brandName': 'HINNIXY',
#   'productLabel': '2-Pack 52 in. Indoor Matte Black 3-Colors LED Ceiling Fan with Dual-Finish Blades and Light Kit and Remote control',
#   'storeSkuNumber': '1011950290',
#   'parentId': '330113954',
#   'modelNumber': 'Y23FSD0019-4802HD',
#   'price': 209.99,
#   'original_price': 209.99,
#   'averageRating': '5.0',
#   'totalReviews': '1',
#   'inventory': 98},
#  {'label': 'New This Season',
#   'itemId': '329398445',
#   'canonicalUrl': '/p/Sawyer-52-in-Integrated-LED-Indoor-Clear-Blade-Gold-Ceiling-Fans-with-Light-and-Remote-Control-Included-30007-GT/329398445',
#   'brandName': None,
#   'productLabel': 'Sawyer 52 in. Integrated LED Indoor Clear-Blade Gold Ceiling Fans with Light and Remote Control Included',
#   'storeSkuNumber': '1011138322',
#   'parentId': '327606411',
#   'modelNumber': '30007-GT',
#   'price': 125.0,
#   'original_price': 147.06,
#   'averageRating': '4.2593',
#   'totalReviews': '27',
#   'inventory': 228}]

# %%
import pandas as pd

# %%
df = pd.read_excel('ceiling_fans_with_lights_2024-09-19.xlsx')
print(df.Order)
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 273    274
# 274    275
# 275    276
# 276    277
# 277    278
# Name: Order, Length: 278, dtype: int64

# %%
duplicates = df[df.duplicated(subset=df.columns.difference(['Order']), keep=False)]

# %%
duplicates
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Order, label, itemId, canonicalUrl, brandName, productLabel, storeSkuNumber, parentId, modelNumber, price, original_price, averageRating, totalReviews, inventory, scraped_time]
# Index: []
